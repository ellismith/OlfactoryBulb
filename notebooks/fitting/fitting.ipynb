# %%
import os; os.chdir('..')
import multiprocessing
from prev_ob_models.Birgiolas2020.fitting import *
# Out:
# /home/justas/anaconda2/envs/p27/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Could not load NEURONBackend

# %%
cell_type = "mc"; cell_id = 1
fitter = CellFitter(cell_type=cell_type, fitting_model_class="prev_ob_models.Birgiolas2020.isolated_cells."+cell_type.upper()+str(cell_id))
fitter.clear_cache()
# Out:
# ('Starting mc FITTER for model:', 'prev_ob_models.Birgiolas2020.isolated_cells.MC1')

# %%
fitter.fit(int(multiprocessing.cpu_count()*1.5), 75)
# Out:
# ('STARTED GEN', 'ZERO', 'size', 24)
# ('DONE with', 1, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '12.69')
# ('DONE with', 2, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '7.54')
# ('DONE with', 3, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '10.50')
# ('DONE with', 4, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '20.26')
# ('DONE with', 5, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '18.23')
# ('DONE with', 6, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '120.93')
# ('DONE with', 7, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '22.44')
# ('DONE with', 8, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '11.06')
# ('DONE with', 9, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '7.29')
# ('DONE with', 10, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '8.00')
# ('DONE with', 11, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '7.47')
# ('DONE with', 12, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '35.05')
# ('DONE with', 13, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '94.66')
# ...

# %%
cell_type = "gc"; cell_id = 2
fitter = CellFitter(cell_type=cell_type, fitting_model_class="prev_ob_models.Birgiolas2020.isolated_cells."+cell_type.upper()+str(cell_id))
fitter.clear_cache()
fitter.fit(int(multiprocessing.cpu_count()*1.5), 75)
# Out:
# ('Starting gc FITTER for model:', 'prev_ob_models.Birgiolas2020.isolated_cells.GC2')
# ('STARTED GEN', 'ZERO', 'size', 24)
# ('DONE with', 1, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '11.30')
# ('DONE with', 2, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '55.77')
# ('DONE with', 3, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '50.17')
# ('DONE with', 4, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '17.48')
# ('DONE with', 5, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '69.34')
# ('DONE with', 6, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '30.86')
# ('DONE with', 7, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '8.55')
# ('DONE with', 8, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '19.23')
# ('DONE with', 9, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '8.94')
# ('DONE with', 10, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '11.70')
# ('DONE with', 11, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '11.37')
# ('DONE with', 12, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '16.20')
# ...

# %%
cell_type = "gc"; cell_id = 3
fitter = CellFitter(cell_type=cell_type, fitting_model_class="prev_ob_models.Birgiolas2020.isolated_cells."+cell_type.upper()+str(cell_id))
fitter.clear_cache()
# Out:
# ('Starting gc FITTER for model:', 'prev_ob_models.Birgiolas2020.isolated_cells.GC3')

# %%
fitter.fit(int(multiprocessing.cpu_count()*1.5), 75)
# Out:
# ('STARTED GEN', 'ZERO', 'size', 24)
# ('DONE with', 1, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '53.69')
# ('DONE with', 2, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '39.74')
# ('DONE with', 3, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '17.72')
# ('DONE with', 4, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '266.08')
# ('DONE with', 5, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '21.79')
# ('DONE with', 6, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '72.41')
# ('DONE with', 7, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '59.46')
# ('DONE with', 8, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '7.29')
# ('DONE with', 9, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '34.16')
# ('DONE with', 10, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '130.34')
# ('DONE with', 11, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '19.82')
# ('DONE with', 12, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '24.63')
# ('DONE with', 13, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '64.88')
# ...

# %%
cell_type = "gc"; cell_id = 4
fitter = CellFitter(cell_type=cell_type, fitting_model_class="prev_ob_models.Birgiolas2020.isolated_cells."+cell_type.upper()+str(cell_id))
fitter.clear_cache()
# Out:
# ('Starting gc FITTER for model:', 'prev_ob_models.Birgiolas2020.isolated_cells.GC4')

# %%
fitter.fit(int(multiprocessing.cpu_count()*1.5), 75)
# Out:
# ('STARTED GEN', 'ZERO', 'size', 24)
# ('DONE with', 1, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '7.95')
# ('DONE with', 2, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '53.48')
# ('DONE with', 3, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '13.29')
# ('DONE with', 4, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '51.84')
# ('DONE with', 5, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '63.17')
# ('DONE with', 6, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '77.46')
# ('DONE with', 7, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '68.62')
# ('DONE with', 8, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '46.49')
# ('DONE with', 9, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '71.72')
# ('DONE with', 10, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '40.68')
# ('DONE with', 11, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '94.53')
# ('DONE with', 12, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '76.87')
# ('DONE with', 13, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '28.50')
# ...

# %%
cell_type = "gc"; cell_id = 5
fitter = CellFitter(cell_type=cell_type, fitting_model_class="prev_ob_models.Birgiolas2020.isolated_cells."+cell_type.upper()+str(cell_id))
fitter.clear_cache()
fitter.fit(int(multiprocessing.cpu_count()*1.5), 75)
# Out:
# ('Starting gc FITTER for model:', 'prev_ob_models.Birgiolas2020.isolated_cells.GC5')
# /home/justas/anaconda2/envs/p27/lib/python2.7/site-packages/deap/creator.py:141: RuntimeWarning: A class named 'FitnessMin' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   RuntimeWarning)
# /home/justas/anaconda2/envs/p27/lib/python2.7/site-packages/deap/creator.py:141: RuntimeWarning: A class named 'Individual' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   RuntimeWarning)
# ('STARTED GEN', 'ZERO', 'size', 24)
# ('DONE with', 1, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '23.83')
# ('DONE with', 2, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '204.34')
# ('DONE with', 3, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '12.02')
# ('DONE with', 4, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '20.39')
# ...

# %%
import os; os.chdir('..')
import multiprocessing
from prev_ob_models.Birgiolas2020.fitting import *
cell_type = "tc"; cell_id = 1
fitter = CellFitter(cell_type=cell_type, fitting_model_class="prev_ob_models.Birgiolas2020.isolated_cells."+cell_type.upper()+str(cell_id))
fitter.clear_cache()
# Out:
# /home/justas/anaconda2/envs/p27/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Could not load NEURONBackend
# ('Starting tc FITTER for model:', 'prev_ob_models.Birgiolas2020.isolated_cells.TC1')

# %%
fitter.fit(int(multiprocessing.cpu_count()*1.5), 75)
# Out:
# ('STARTED GEN', 'ZERO', 'size', 24)
# ('DONE with', 1, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '18.46')
# ('DONE with', 2, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '12.24')
# ('DONE with', 3, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '49.38')
# ('DONE with', 4, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '23.80')
# ('DONE with', 5, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '15.64')
# ('DONE with', 6, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '10.25')
# ('DONE with', 7, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '10.16')
# ('DONE with', 8, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '23218.40')
# ('DONE with', 9, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '18.23')
# ('DONE with', 10, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '15.68')
# ('DONE with', 11, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '12.20')
# ('DONE with', 12, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '15.18')
# ('DONE with', 13, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '20.31')
# ...

# %%
cell_type = "tc"; cell_id = 2
fitter = CellFitter(cell_type=cell_type, fitting_model_class="prev_ob_models.Birgiolas2020.isolated_cells."+cell_type.upper()+str(cell_id))
fitter.clear_cache()
fitter.fit(int(multiprocessing.cpu_count()*1.5), 75)
# Out:
# ('Starting tc FITTER for model:', 'prev_ob_models.Birgiolas2020.isolated_cells.TC2')
# /home/justas/anaconda2/envs/p27/lib/python2.7/site-packages/deap/creator.py:141: RuntimeWarning: A class named 'FitnessMin' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   RuntimeWarning)
# /home/justas/anaconda2/envs/p27/lib/python2.7/site-packages/deap/creator.py:141: RuntimeWarning: A class named 'Individual' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   RuntimeWarning)
# ('STARTED GEN', 'ZERO', 'size', 24)
# ('DONE with', 1, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '4.83')
# ('DONE with', 2, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '9.20')
# ('DONE with', 3, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '18.31')
# ('DONE with', 4, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '19.93')
# ...

# %%
cell_type = "tc"; cell_id = 3
fitter = CellFitter(cell_type=cell_type, fitting_model_class="prev_ob_models.Birgiolas2020.isolated_cells."+cell_type.upper()+str(cell_id))
fitter.clear_cache()
fitter.fit(int(multiprocessing.cpu_count()*1.5), 75)
# Out:
# ('Starting tc FITTER for model:', 'prev_ob_models.Birgiolas2020.isolated_cells.TC3')
# /home/justas/anaconda2/envs/p27/lib/python2.7/site-packages/deap/creator.py:141: RuntimeWarning: A class named 'FitnessMin' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   RuntimeWarning)
# /home/justas/anaconda2/envs/p27/lib/python2.7/site-packages/deap/creator.py:141: RuntimeWarning: A class named 'Individual' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   RuntimeWarning)
# ('STARTED GEN', 'ZERO', 'size', 24)
# ('DONE with', 1, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '11.23')
# ('DONE with', 2, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '9.94')
# ('DONE with', 3, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '11.23')
# ('DONE with', 4, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '20.92')
# ...

# %%
cell_type = "tc"; cell_id = 4
fitter = CellFitter(cell_type=cell_type, fitting_model_class="prev_ob_models.Birgiolas2020.isolated_cells."+cell_type.upper()+str(cell_id))
fitter.clear_cache()
fitter.fit(int(multiprocessing.cpu_count()*1.5), 75)
# Out:
# ('Starting tc FITTER for model:', 'prev_ob_models.Birgiolas2020.isolated_cells.TC4')
# ('STARTED GEN', 'ZERO', 'size', 24)
# ('DONE with', 1, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '48.17')
# ('DONE with', 2, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '14.65')
# ('DONE with', 3, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '19.18')
# ('DONE with', 4, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '7.99')
# ('DONE with', 5, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '32.22')
# ('DONE with', 6, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '14.28')
# ('DONE with', 7, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '21.70')
# ('DONE with', 8, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '80.88')
# ('DONE with', 9, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '19.99')
# ('DONE with', 10, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '223.85')
# ('DONE with', 11, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '15.08')
# ('DONE with', 12, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '90.00')
# ...

# %%
cell_type = "tc"; cell_id = 5
fitter = CellFitter(cell_type=cell_type, fitting_model_class="prev_ob_models.Birgiolas2020.isolated_cells."+cell_type.upper()+str(cell_id))
fitter.clear_cache()
fitter.fit(int(multiprocessing.cpu_count()*1.5), 75)
# Out:
# ('Starting tc FITTER for model:', 'prev_ob_models.Birgiolas2020.isolated_cells.TC5')
# ('List', 'axonal', 'not found in cell', 'TC5', 'Skipping list...')
# ('List', 'axonal', 'not found in cell', 'TC5', 'Skipping list...')
# ('List', 'axonal', 'not found in cell', 'TC5', 'Skipping list...')
# ('List', 'axonal', 'not found in cell', 'TC5', 'Skipping list...')
# ('List', 'axonal', 'not found in cell', 'TC5', 'Skipping list...')
# ('List', 'axonal', 'not found in cell', 'TC5', 'Skipping list...')
# ('List', 'axonal', 'not found in cell', 'TC5', 'Skipping list...')
# ('STARTED GEN', 'ZERO', 'size', 24)
# ('List', 'axonal', 'not found in cell', 'TC5', 'Skipping list...')
# ('List', 'axonal', 'not found in cell', 'TC5', 'Skipping list...')
# ('List', 'axonal', 'not found in cell', 'TC5', 'Skipping list...')
# ('List', 'axonal', 'not found in cell', 'TC5', 'Skipping list...')
# ('List', 'axonal', 'not found in cell', 'TC5', 'Skipping list...')
# ...
